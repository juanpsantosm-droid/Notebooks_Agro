# %% [markdown]
# <a href="https://colab.research.google.com/github/juanpsantosm-droid/Notebooks_Agro-2026-01/blob/main/Control_de_Rendimiento_en_Extracci%C3%B3n_de_Aceite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Juan Pablo Santos Meza

# %% [markdown]
# Aquí te explico el código de la celda `2nWZcXjYJMOD` línea por línea:
#
# ```python
# #ENTRADA INGRESA Solicitar el nombre del lote de producción (Tipo string).
# #Solicitar el peso de los racimos en kg (Tipo float)(PR).
# #Solicitar los litros de aceite obtenidos (Tipo float)(Lt).
# ```
# Estas tres líneas son **comentarios**. Indican que las siguientes líneas de código se encargarán de solicitar la información de entrada al usuario, como el nombre del lote, el peso de los racimos y los litros de aceite. Los comentarios no son ejecutados por Python, solo sirven como notas para entender el código.
#
# ```python
# NOMBRE = input("Ingrese el nombre del lote: ")
# ```
# Esta línea solicita al usuario que ingrese el nombre del lote de producción. La función `input()` muestra el mensaje "Ingrese el nombre del lote: " en la consola y espera a que el usuario escriba algo y presione Enter. El valor ingresado por el usuario (que siempre es una cadena de texto o `string`) se almacena en la variable `NOMBRE`.
#
# ```python
# PR = float(input("Ingrese el peso de los racimos en kg: "))
# ```
# Similar a la línea anterior, esta línea solicita el peso de los racimos en kilogramos. La diferencia es que, después de que el usuario ingresa un valor, la función `float()` convierte esa cadena de texto en un número de punto flotante (`float`). Esto es necesario porque el peso puede tener decimales. El valor numérico se guarda en la variable `PR`.
#
# ```python
# Lt = float(input("Ingrese los litros de aceite obtenidos: "))
# ```
# De manera similar, esta línea solicita los litros de aceite obtenidos. La función `input()` obtiene el texto, y `float()` lo convierte a un número de punto flotante. El resultado se almacena en la variable `Lt`.
#
# ```python
# #PROCESO CALCULAR EL PESO DEL ACEITE(PA) Y EL RENDIMIENTO (r)
# ```
# Este es otro **comentario** que indica que las siguientes líneas de código realizarán los cálculos necesarios para obtener el peso del aceite y el rendimiento.
#
# ```python
# PA = Lt * 0.92
# ```
# Aquí se calcula el **peso del aceite (PA)**. Se multiplica la cantidad de litros de aceite (`Lt`) por la densidad aproximada del aceite, que es `0.92` kg/L. El resultado (que también será un `float`) se almacena en la variable `PA`.
#
# ```python
# r = (PA / PR) * 100
# ```
# Esta línea calcula el **rendimiento (r)**. Se divide el peso del aceite (`PA`) entre el peso total de los racimos (`PR`) y luego se multiplica por `100` para expresar el resultado como un porcentaje. El valor del rendimiento (un `float`) se guarda en la variable `r`.
#
# ```python
# #SALIDA
# ```
# Este es un **comentario** que señala que la siguiente línea se encargará de mostrar los resultados al usuario.
#
# ```python
# print("El rendimiento del lote", NOMBRE, "es del", r, "%")
# ```
# Finalmente, esta línea muestra el resultado en la consola. La función `print()` concatena (une) varias partes: las cadenas de texto "El rendimiento del lote", "es del" y " %", junto con los valores de las variables `NOMBRE` y `r`. El resultado final es un mensaje informativo que muestra el nombre del lote y su rendimiento calculado.

# %% [markdown]
# #*Control de Rendimiento en Extracción de Aceite*
#
# Este ejercicio es ideal para introducir float, int y la concatenación de strings.
#
# **Planteamiento:**
# Una planta procesadora de palma de aceite necesita calcular el **Índice de Rendimiento de Extracción** (IRE). El operario debe ingresar el **peso total de los racimos de fruta fresca** (RFF) procesados en kilogramos y la cantidad de aceite crudo obtenido en litros.
#
# **Requerimientos:**
#
# 1. Solicitar el nombre del lote de producción (Tipo string).
# 2. Solicitar el peso de los racimos en kg (Tipo float)(PR).
# 3. Solicitar los litros de aceite obtenidos (Tipo float)(Lt).
# 4. Calcular el rendimiento sabiendo que la densidad aproximada del aceite es de 0.92 kg/L
# (r).
# $$Peso Aceite (PA)=Lt*0.92$$
#
#
# $$ r=(PA/PR)×100$$
#
# Prueba del programa:
#
# **Si se ingresan 1000 kg de racimos y se obtienen 200 litros de aceite, el programa debe informar que el rendimiento del lote es del 18.4%.**

# %%
#ENTRADA INGRESA  Solicitar el nombre del lote de producción (Tipo string).
#Solicitar el peso de los racimos en kg (Tipo float)(PR).
#Solicitar los litros de aceite obtenidos (Tipo float)(Lt).
NOMBRE = input("Ingrese el nombre del lote: ")
PR = float(input("Ingrese el peso de los racimos en kg: "))
Lt = float(input("Ingrese los litros de aceite obtenidos: "))

#PROCESO CALCULAR EL PESO DEL ACEITE(PA) Y EL RENDIMIENTO (r)
PA = Lt * 0.92
r = (PA / PR) * 100

#SALIDA
print("El rendimiento del lote", NOMBRE, "es del", r, "%")

trprint
# Out:
# Ingrese el nombre del lote: PUERTA ROJA
# Ingrese el peso de los racimos en kg: 25
# Ingrese los litros de aceite obtenidos: 25
# El rendimiento del lote PUERTA ROJA es del 92.0 %
